# %% [markdown]
# ## Use Pretrained ResNet50 for Feature Extraction of SVI

# %%
# import
import os
import time
import numpy as np
import torch
from torchvision import models, transforms
from PIL import Image
import matplotlib.pyplot as plt

# Initialize device (use GPU if available, otherwise fallback to CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load pretrained ResNet-50 model for feature extraction
model = models.resnet50(weights=ResNet50_Weights.DEFAULT) 
model.fc = torch.nn.Identity()  # Replace the fully connected layer with an identity mapping to extract features
model = model.to(device)
model.eval()  # Set model to evaluation mode

# Define preprocessing steps for input images
preprocess = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize images to 224x224 pixels
    transforms.ToTensor(),  # Convert image to PyTorch tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize using ImageNet statistics
])


# Function to extract features from an image
def extract_features(image_path, model, preprocess, device):
    """
    Extracts feature vectors from a given image using a pre-trained model.
    
    Parameters:
    - image_path (str): Path to the input image.
    - model: Pre-trained PyTorch model used for feature extraction.
    - preprocess: Transformation pipeline applied to the image before inference.
    - device: The device (CPU or GPU) on which the model is running.
    
    Returns:
    - np.ndarray: Extracted feature vector, or None if an error occurs.
    """
    try:
        # Load and preprocess the image
        image = Image.open(image_path).convert('RGB')
        input_tensor = preprocess(image).unsqueeze(0).to(device)
        
        # Perform inference without tracking gradients
        with torch.no_grad():
            features = model(input_tensor)
        
        return features.cpu().numpy().flatten()
    except Exception as e:
        print(f"Error processing image {image_path}: {e}")
        return None  # Return None if extraction fails

# %% [markdown]
# ## Pre-feature extraction estimations
#
# This project contains many computationally and time-intensive processes. There is only so much optimization for space and time that can be performed. However, in order to properly plan for each part of this process, a new implementation of the spring semester has been to include estimations for both space and time *before* running all code. Doing such estimations helps to avoid hitting data limits, and to plan out times to have my personal computer running. In the following sections, I estimate the processing time to perform feature extraction for ~105 census tracts.

# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt

def estimate_processing_time_and_visualize(root_dir, model, preprocess, device, dataset_name, max_samples=100):
    """
    Estimates the processing time for extracting features from images in a given directory and visualizes results.
    
    Parameters:
    - root_dir (str): Path to the directory containing images.
    - model: Pre-trained model used for feature extraction.
    - preprocess: Preprocessing function for input images.
    - device: Device (CPU/GPU) to run the model on.
    - dataset_name (str): Name of the dataset (used for visualization titles and file naming).
    - max_samples (int, optional): Maximum number of images to process. Default is 100.
    
    Returns:
    - total_images (int): Total number of images found in the directory.
    - avg_time_per_image (float): Average processing time per image.
    - estimated_total_time (float): Estimated total time for processing the entire dataset.
    """
    total_images = 0  # Counter for total images in the directory
    processing_times = []  # List to store processing time per image
    total_processing_times = [0]  # Cumulative processing time
    feature_storage = {}  # Dictionary to store extracted features

    # Walk through the directory structure to find image files
    for subdir, _, files in os.walk(root_dir):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):  # Process only image files
                total_images += 1
                image_path = os.path.join(subdir, file)

                # Measure time taken to extract features for a single image
                start_time = time.time()
                features = extract_features(image_path, model, preprocess, device)
                elapsed_time = time.time() - start_time  # Compute elapsed time
                
                processing_times.append(elapsed_time)  # Store individual processing time
                total_processing_times.append(np.sum(processing_times))  # Store cumulative processing time
                
                # Store extracted features in dictionary
                feature_storage[image_path] = features

                # Stop processing after reaching max_samples limit
                if len(processing_times) >= max_samples:
                    break
        if len(processing_times) >= max_samples:
            break

    # Save extracted features as a NumPy binary file
    features_output_path = f"{dataset_name}_features.npy"
    np.save(features_output_path, feature_storage)
    print(f"Extracted features saved to {features_output_path}")

    # Plot histogram of processing times per image
    plt.figure(figsize=(10, 6))
    plt.hist(processing_times, bins=10, alpha=0.7, color='blue', edgecolor='black')
    plt.title(f"Histogram of Processing Times for {dataset_name}")
    plt.xlabel("Processing Time per Image (seconds)")
    plt.ylabel("Frequency")
    plt.grid(axis='y')
    plt.show()

    # Plot cumulative processing time as a line graph
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(total_processing_times)), total_processing_times, marker='o', linestyle='-', color='green')
    plt.title(f"Processing Time per Image for {dataset_name}")
    plt.xlabel("Image Index")
    plt.ylabel("Processing Time (seconds)")
    plt.grid()
    plt.show()

    # Compute statistics
    avg_time_per_image = np.mean(processing_times)  # Mean processing time per image
    estimated_total_time = avg_time_per_image * total_images  # Estimate total processing time for full dataset

    # Print summary statistics
    print(f"Dataset: {dataset_name}")
    print(f"Total Images: {total_images}")
    print(f"Average Time Per Image: {avg_time_per_image:.4f} seconds")
    print(f"Estimated Total Time: {estimated_total_time / 60:.2f} minutes\n")

    return total_images, avg_time_per_image, estimated_total_time

# Define the directory containing segmented images
segmented_dir = "/Volumes/MRDALLMAYR/data/img_mapillary_images_osm_full"

# Run processing time estimation and visualization for segmented images
echo "Estimating processing time for segmented images..."
estimate_processing_time_and_visualize(segmented_dir, model, preprocess, device, "Segmented Images", max_samples=100)
# Out:
# Estimating processing time for segmented images...
# Extracted features saved to Segmented Images_features.npy
# Dataset: Segmented Images
# Total Images: 100
# Average Time Per Image: 0.3579 seconds
# Estimated Total Time: 0.60 minutes
# (100, 0.35789439916610716, 35.78943991661072)

# %%
# EST TIME for all census tracts (only sampling for 100) 
n_images = 500 * 100  # 500 images * ~ 100 CT 
est_min = (0.3579 * n_images ) / 60 
est_hours = est_min / 60 
print("Estimated Min:", est_min, "Est Hours:", est_hours)
# Out:
# Estimated Min: 298.25 Est Hours: 4.970833333333333

# %%
# EST STORAGE for all image from census tracts (only sampling for 100) 
for_100_imgs = 835 # KB 
per_1 = for_100_imgs / 100
for_all = n_images * per_1
print(for_all, "kB", for_all/1e6, "gB")
# Out:
# 417500.0 kB 0.4175 gB

# %%
import os
import time
import numpy as np
import torch
from torchvision import models, transforms
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from torchvision.models import ResNet50_Weights

# Function to save extracted features for all images in each folder
def save_features_by_folder(root_dir, model, preprocess, device, output_base_dir):
    """
    Extracts and saves features for all images within subdirectories of a given root directory.
    
    Parameters:
    - root_dir (str): Path to the root directory containing image folders.
    - model: Pre-trained PyTorch model used for feature extraction.
    - preprocess: Image transformation pipeline.
    - device: The device (CPU or GPU) to use for inference.
    - output_base_dir (str): Directory where extracted feature files will be saved.
    """
    for subdir, _, files in os.walk(root_dir):
        folder_name = os.path.basename(subdir)
        output_path = os.path.join(output_base_dir, f"features_{folder_name}.npy")
        
        # Skip folder if features already saved
        if os.path.exists(output_path):
            print(f"Skipping folder {folder_name}, features already exist at {output_path}")
            continue

        feature_storage = {}

        # Extract features for each image
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                image_path = os.path.join(subdir, file)
                features = extract_features(image_path, model, preprocess, device)
                if features is not None:
                    feature_storage[image_path] = features

        # Save extracted features if available
        if feature_storage:
            np.save(output_path, feature_storage)
            print(f"Features for folder {folder_name} saved to {output_path}")
        else:
            print(f"No valid images found in folder {folder_name}.")

# Paths to input data and output directory
segmented_dir = "/Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented"
output_dir = "/Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations"
os.makedirs(output_dir, exist_ok=True)

# Extract features for all images and save results
print("Processing all folders and saving features...")
save_features_by_folder(segmented_dir, model, preprocess, device, output_dir)
# Out:
# Estimating processing time for 100 samples...
# Average Time Per Image: 0.4701 seconds
# Estimated Total Time for 100 images: 0.78 minutes
# Processing all folders and saving features...
# No valid images found in folder mapillary_osm_imgs_segmented.
# Skipping folder 48201220500, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201220500.npy
# Skipping folder 48201312700, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201312700.npy
# Skipping folder 48201314401, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201314401.npy
# Skipping folder 48201450900, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201450900.npy
# Skipping folder 48201521202, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201521202.npy
# Skipping folder 48201332300, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201332300.npy
# Skipping folder 48201211302, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201211302.npy
# Skipping folder 48201450401, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201450401.npy
# Skipping folder 48201432704, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201432704.npy
# Skipping folder 48201321002, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201321002.npy
# Skipping folder 48201450700, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201450700.npy
# Skipping folder 48201331602, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201331602.npy
# Skipping folder 48201313802, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201313802.npy
# Skipping folder 48201510301, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201510301.npy
# Skipping folder 48201534203, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201534203.npy
# Skipping folder 48201413301, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201413301.npy
# Skipping folder 48201530400, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201530400.npy
# Skipping folder 48201332800, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201332800.npy
# Skipping folder 48201543201, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201543201.npy
# Skipping folder 48201310700, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201310700.npy
# Skipping folder 48201533100, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201533100.npy
# Skipping folder 48201413302, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201413302.npy
# Skipping folder 48201540700, features already saved at /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201540700.npy
# Features for folder 48201221400 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201221400.npy
# Features for folder 48201312200 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201312200.npy
# Features for folder 48201211600 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201211600.npy
# Features for folder 48201411600 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201411600.npy
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201411200/459004171847700_blend.png: broken data stream when reading image file
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201411200/520619712649283_blend.png: broken PNG file (chunk b'\x00\x00\x00\x00')
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201411200/786269882286697_blend.png: broken PNG file (chunk b'\x80\x82\xecL')
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201411200/298080975123930_blend.png: broken data stream when reading image file
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201411200/1120358455130050_blend.png: broken PNG file (chunk b'\x00\x00\x00\x00')
# Features for folder 48201411200 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201411200.npy
# Features for folder 48201510601 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201510601.npy
# Features for folder 48201320202 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201320202.npy
# Features for folder 48201333906 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201333906.npy
# Features for folder 48201550201 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201550201.npy
# Features for folder 48201312901 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201312901.npy
# Features for folder 48201521100 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201521100.npy
# Features for folder 48201313801 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201313801.npy
# Features for folder 48201311300 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201311300.npy
# Features for folder 48201510202 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201510202.npy
# Features for folder 48201310500 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201310500.npy
# Features for folder 48201541702 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201541702.npy
# Features for folder 48201450301 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201450301.npy
# Features for folder 48201451301 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201451301.npy
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201520301/548407449481519_blend.png: image file is truncated
# Features for folder 48201520301 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201520301.npy
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201320500/540644277094814_blend.png: broken PNG file (chunk b'!QUU')
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201320500/318401473007193_blend.png: image file is truncated
# Features for folder 48201320500 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201320500.npy
# Features for folder 48201451902 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201451902.npy
# Features for folder 48201521201 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201521201.npy
# Features for folder 48201451005 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201451005.npy
# Features for folder 48201410703 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201410703.npy
# Features for folder 48201532800 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201532800.npy
# Features for folder 48201220200 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201220200.npy
# Features for folder 48201410102 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201410102.npy
# Features for folder 48201530502 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201530502.npy
# Features for folder 48201332400 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201332400.npy
# Features for folder 48201321101 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201321101.npy
# Features for folder 48201321800 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201321800.npy
# Features for folder 48201330801 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201330801.npy
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201332100/853140015276498_blend.png: broken PNG file (chunk b'\x98\x1d\x1b0')
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201332100/158913862840829_blend.png: broken data stream when reading image file
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201332100/465116311231205_blend.png: cannot identify image file '/Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201332100/465116311231205_blend.png'
# Features for folder 48201332100 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201332100.npy
# Features for folder 48201532302 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201532302.npy
# Features for folder 48201240802 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201240802.npy
# Features for folder 48201333700 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201333700.npy
# Features for folder 48201334102 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201334102.npy
# Features for folder 48201321302 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201321302.npy
# Features for folder 48201520601 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201520601.npy
# No valid images found in folder pixel_ratio_checkpoints.
# Features for folder 48201333903 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201333903.npy
# Features for folder 48201450200 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201450200.npy
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201430700/288073402980336_blend.png: broken PNG file (chunk b'\x90\xc0f\xc7')
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201430700/189287849732741_blend.png: broken PNG file (chunk b'MTK)')
# Features for folder 48201430700 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201430700.npy
# Features for folder 48201410602 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201410602.npy
# Features for folder 48201530501 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201530501.npy
# Features for folder 48201510701 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201510701.npy
# Features for folder 48201221100 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201221100.npy
# Features for folder 48201410402 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201410402.npy
# Features for folder 48201311701 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201311701.npy
# Features for folder 48201450402 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201450402.npy
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201310102/321584776046490_blend.png: broken PNG file (chunk b'\x8c\xab\x95\x04')
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201310102/313715780192400_blend.png: cannot identify image file '/Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201310102/313715780192400_blend.png'
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201310102/930324707779332_blend.png: image file is truncated
# Features for folder 48201310102 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201310102.npy
# Features for folder 48201510400 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201510400.npy
# Features for folder 48201454502 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201454502.npy
# Features for folder 48201211900 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201211900.npy
# Features for folder 48201320901 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201320901.npy
# Features for folder 48201411503 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201411503.npy
# Features for folder 48201100001 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201100001.npy
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201533302/919543975547424_blend.png: image file is truncated
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201533302/466023428022320_blend.png: cannot identify image file '/Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201533302/466023428022320_blend.png'
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201533302/193682022576074_blend.png: broken PNG file (chunk b'x\x8d<%')
# Features for folder 48201533302 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201533302.npy
# Features for folder 48201310600 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201310600.npy
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201520302/466642574603683_blend.png: broken PNG file (chunk b's\x02v[')
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201520302/309014177267471_blend.png: broken PNG file (chunk b'\xb0\x13{Y')
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201520302/821082538791059_blend.png: Truncated File Read
# Features for folder 48201520302 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201520302.npy
# Features for folder 48201410300 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201410300.npy
# Features for folder 48201451004 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201451004.npy
# Features for folder 48201432705 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201432705.npy
# Features for folder 48201510702 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201510702.npy
# Features for folder 48201324200 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201324200.npy
# Features for folder 48201530200 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201530200.npy
# Features for folder 48201452103 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201452103.npy
# Features for folder 48201550202 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201550202.npy
# Features for folder 48201410706 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201410706.npy
# Features for folder 48201314302 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201314302.npy
# Features for folder 48201313000 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201313000.npy
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201313500/464397707968087_blend.png: broken PNG file (chunk b'\xfa\xe9/\xb7')
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201313500/581212976106438_blend.png: cannot identify image file '/Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201313500/581212976106438_blend.png'
# Features for folder 48201313500 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201313500.npy
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201522402/2949153635369520_blend.png: broken data stream when reading image file
# Features for folder 48201522402 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201522402.npy
# Features for folder 48201511100 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201511100.npy
# Features for folder 48201221301 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201221301.npy
# Features for folder 48201510803 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201510803.npy
# Features for folder 48201533500 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201533500.npy
# Features for folder 48201310200 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201310200.npy
# Features for folder 48201222602 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201222602.npy
# Features for folder 48201312502 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201312502.npy
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201220300/480875903148365_blend.png: broken data stream when reading image file
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201220300/308585434136523_blend.png: broken data stream when reading image file
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201220300/153014426794730_blend.png: broken PNG file (chunk b'P1Q\x99')
# Features for folder 48201220300 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201220300.npy
# Features for folder 48201333904 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201333904.npy
# Features for folder 48201510201 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201510201.npy
# Error processing image /Volumes/MRDALLMAYR/data/mapillary_osm_imgs_segmented/48201311800/2927605767516398_blend.png: unrecognized data stream contents when reading image file
# Features for folder 48201311800 saved to /Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations/features_48201311800.npy

# %% [markdown]
# ## Compare feature extraction divergences and average behavior between sample sizes of 100, 200, 300, 400, and 500 images

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from scipy.spatial.distance import jensenshannon

# Define the folder containing the .npy files of extracted features 
folder_path = "/Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations" 

# Get all .npy feature files
feature_files = [f for f in os.listdir(folder_path) if f.endswith(".npy")]

# Dictionary to store results for each census tract
tract_results = {}

# Define sample sizes
sample_sizes = [100, 200, 300, 400, 500]

# Loop through each .npy file (each representing a different census tract)
for file in feature_files:
    tract_name = file.replace(".npy", "")  # Extract tract identifier
    file_path = os.path.join(folder_path, file)

    # Load features
    features_dict = np.load(file_path, allow_pickle=True).item()
    feature_vectors = np.array(list(features_dict.values()))  # 2048D feature vectors

    # Check available images and adjust sample sizes if necessary
    max_size = min(500, feature_vectors.shape[0])
    valid_sample_sizes = [s for s in sample_sizes if s <= max_size]

    # Store results for this tract
    tract_results[tract_name] = {"variance": {}, "js_divergence": {}}

    prev_distribution = None

    for size in valid_sample_sizes:
        # Sample `size` images randomly
        sampled_indices = np.random.choice(range(feature_vectors.shape[0]), size, replace=False)
        sampled_features = feature_vectors[sampled_indices]

        # Compute total variance across all 2048 feature dimensions
        total_variance = np.var(sampled_features, axis=0).sum()
        tract_results[tract_name]["variance"][size] = total_variance

        # Compute JS divergence with the previous sample size distribution
        if prev_distribution is not None:
            # Normalize feature distributions
            prev_hist, _ = np.histogram(prev_distribution.flatten(), bins=50, density=True)
            curr_hist, _ = np.histogram(sampled_features.flatten(), bins=50, density=True)
            js_div = jensenshannon(prev_hist, curr_hist)
            tract_results[tract_name]["js_divergence"][size] = js_div

        prev_distribution = sampled_features

# Convert results to DataFrames for comparison
variance_df = pd.DataFrame({tract: tract_results[tract]["variance"] for tract in tract_results})
js_divergence_df = pd.DataFrame({tract: tract_results[tract]["js_divergence"] for tract in tract_results})

# Create boxplot for variance across sample sizes
plt.figure(figsize=(12, 6))
sns.boxplot(data=variance_df.T)  # Transpose so sample sizes are on x-axis
plt.xlabel("Sample Size")
plt.ylabel("Total Feature Variance")
plt.title("Feature Space Variance Across Census Tracts")
plt.xticks(rotation=45)
plt.show()

# Create boxplot for JS divergence across sample sizes
plt.figure(figsize=(12, 6))
sns.boxplot(data=js_divergence_df.T)  # Transpose so sample sizes are on x-axis
plt.xlabel("Sample Size")
plt.ylabel("Jensen-Shannon Divergence")
plt.title("Feature Distribution Shift (JS Divergence) Across Census Tracts")
plt.xticks(rotation=45)
plt.show()

# Create heatmap for variance trends
plt.figure(figsize=(12, 8))
sns.heatmap(variance_df, cmap="viridis", annot=False, linewidths=0.5)
plt.xlabel("Census Tract")
plt.ylabel("Sample Size")
plt.title("Heatmap of Feature Variance Across Census Tracts")
plt.show()

# Create heatmap for JS divergence trends
plt.figure(figsize=(12, 8))
sns.heatmap(js_divergence_df, cmap="coolwarm", annot=False, linewidths=0.5)
plt.xlabel("Census Tract")
plt.ylabel("Sample Size")
plt.title("Heatmap of JS Divergence Across Census Tracts")
plt.show()

# %%
# Convert results to DataFrames for comparison
variance_df = pd.DataFrame({tract: tract_results[tract]["variance"] for tract in tract_results})
js_divergence_df = pd.DataFrame({tract: tract_results[tract]["js_divergence"] for tract in tract_results})

# Compute confidence intervals for variance and JS divergence
variance_mean = variance_df.mean(axis=1)
variance_std = variance_df.std(axis=1)
js_div_mean = js_divergence_df.mean(axis=1)
js_div_std = js_divergence_df.std(axis=1)

print("Variance DataFrame:")
print(variance_df)
print("\nVariance Mean and Std:")
print(pd.DataFrame({'Mean': variance_mean, 'Std': variance_std}))

print("\nJensen-Shannon Divergence DataFrame:")
print(js_divergence_df)
print("\nJS Divergence Mean and Std:")
print(pd.DataFrame({'Mean': js_div_mean, 'Std': js_div_std}))
# Out:
# Variance DataFrame:
#      features_48201451005  features_48201410703  features_48201332100  \
# 100             75.488152             88.352364             61.737564
# 200             79.109535             88.578217             61.637150
# 300             77.851212             89.385818             61.533691
# 400             77.570702             90.141106             60.957275
# 500             77.034203             89.779465                   NaN
#
#      features_48201211900  features_48201321800  features_48201510702  \
# 100             59.969650             55.048714             79.459839
# 200             60.091991             59.511604             83.381943
# 300             61.327808             57.938347             83.391174
# 400             61.527061             57.628181             84.503876
# 500             61.294647             57.641014                   NaN
#
#      features_48201451004  features_48201530200  features_48201332300  \
# 100             76.318031             93.448151             56.878475
# 200             74.763588             92.554855             60.201122
# 300             74.049057             91.542007             59.912682
# 400             76.983757             93.520195             61.155548
# 500             76.634293                   NaN             60.874321
#
#      features_48201220300  ...  features_48201411600  features_48201311701  \
# 100             62.279346  ...             81.222626             66.246147
# 200             62.557312  ...             82.058746             71.622360
# 300             61.747879  ...             84.325401             70.868225
# 400             62.736191  ...             86.941910             70.037781
# 500                   NaN  ...             85.589188             69.818130
#
#      features_48201411200  features_48201540700  features_48201450301  \
# 100             73.137581             58.341663             67.759903
# 200             78.623718             57.106918             69.751839
# 300             79.555473             55.952385             69.063095
# 400             79.777420             57.025749             70.788208
# 500                   NaN             57.138344             69.880295
#
#      features_48201532800  features_48201221400  features_48201521100  \
# 100             67.568481             67.784393             70.266670
# 200             68.678726             66.335716             72.061058
# 300             68.221207             67.357140             72.810844
# 400             68.882759             67.792999             70.837364
# 500             68.438583             67.414246             71.478973
#
#      features_48201533302  features_48201533100
# 100             57.335182             58.224510
# 200             53.346809             59.721809
# 300             52.965118             60.962486
# 400             53.760853             60.339867
# 500                   NaN             60.000191
#
# [5 rows x 105 columns]
#
# Variance Mean and Std:
#           Mean        Std
# 100  72.086616  12.755191
# 200  72.508553  13.266894
# 300  72.309928  13.081719
# 400  72.570912  13.243659
# 500  72.248567  12.715660
#
# Jensen-Shannon Divergence DataFrame:
#      features_48201451005  features_48201410703  features_48201332100  \
# 200              0.007208              0.007001              0.017429
# 300              0.010711              0.004923              0.004343
# 400              0.002129              0.004418              0.002530
# 500              0.001128              0.001135                   NaN
#
#      features_48201211900  features_48201321800  features_48201510702  \
# 200              0.006019              0.008650              0.006397
# 300              0.003321              0.022595              0.004933
# 400              0.007548              0.002189              0.002516
# 500              0.001772              0.001124                   NaN
#
#      features_48201451004  features_48201530200  features_48201332300  \
# 200              0.031771              0.021396              0.006319
# 300              0.003334              0.024955              0.008698
# 400              0.002169              0.002152              0.004773
# 500              0.001004                   NaN              0.001234
#
#      features_48201220300  ...  features_48201411600  features_48201311701  \
# 200              0.008271  ...              0.006313              0.029117
# 300              0.003784  ...              0.003890              0.018402
# 400              0.001980  ...              0.015813              0.013978
# 500                   NaN  ...              0.001264              0.001036
#
#      features_48201411200  features_48201540700  features_48201450301  \
# 200              0.007874              0.005747              0.013526
# 300              0.003488              0.004044              0.014657
# 400              0.013575              0.002625              0.002782
# 500                   NaN              0.019049              0.001423
#
#      features_48201532800  features_48201221400  features_48201521100  \
# 200              0.029790              0.011727              0.009237
# 300              0.003455              0.003767              0.008477
# 400              0.012834              0.002116              0.006938
# 500              0.002118              0.001840              0.006508
#
#      features_48201533302  features_48201533100
# 200              0.015145              0.005469
# 300              0.006131              0.004670
# 400              0.002289              0.003119
# 500                   NaN              0.001448
#
# [4 rows x 105 columns]
#
# JS Divergence Mean and Std:
#          Mean       Std
# 200  0.014398  0.009765
# 300  0.010077  0.008119
# 400  0.007269  0.007372
# 500  0.002730  0.004401

# %% [markdown]
# ## PCA Analysis

# %%
# Get all .npy feature files
folder_path = "/Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations" 

feature_files = [f for f in os.listdir(folder_path) if f.endswith(".npy")]

# Dictionary to store feature vectors for each census tract
tract_features = {}

# Load feature vectors from each .npy file
for file in feature_files:
    tract_name = file.replace(".npy", "")  # Extract tract identifier
    file_path = os.path.join(folder_path, file)
    features_dict = np.load(file_path, allow_pickle=True).item()
    tract_features[tract_name] = np.array(list(features_dict.values()))  # Convert to NumPy array

# Combine all feature vectors across tracts for PCA
all_features = np.vstack(list(tract_features.values()))

# Apply PCA across all tracts
pca = PCA(n_components=0.95)  # Keep enough components to explain 95% variance
pca.fit(all_features)

# Transform each tract using the same PCA model and store labeled components
tract_pca_results = {}
for tract in tract_features:
    transformed_features = pca.transform(tract_features[tract])
    tract_pca_results[tract] = {f"PCA_{i+1}": transformed_features[:, i] for i in range(transformed_features.shape[1])}

# Print PCA explained variance ratio
print("Explained Variance Ratio:", pca.explained_variance_ratio_)

# Plot cumulative explained variance to visualize how many components are needed for 95%
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o', linestyle='-')
plt.axhline(y=0.95, color='r', linestyle='--', label='95% Variance Threshold')
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("PCA Explained Variance Analysis")
plt.legend()
plt.grid()
plt.show()

# Print the number of components needed to reach 95% variance
num_components_95 = np.argmax(cumulative_variance >= 0.95) + 1
print(f"Number of Principal Components needed to retain 95% variance: {num_components_95}")

# Randomly select 5 tracts to display PCA scatter plots
selected_tracts = random.sample(list(tract_pca_results.keys()), min(5, len(tract_pca_results)))

# Create subplots for selected tracts
fig, axes = plt.subplots(len(selected_tracts), 1, figsize=(10, 6 * len(selected_tracts)))
if len(selected_tracts) == 1:
    axes = [axes]  # Ensure iterable if only one subplot

for ax, tract in zip(axes, selected_tracts):
    ax.scatter(tract_pca_results[tract]["PCA_1"], tract_pca_results[tract]["PCA_2"], alpha=0.4, label=f"Tract {tract}")
    ax.set_title(f"PCA Projection - Tract {tract}")
    ax.set_xlabel("PCA Component 1")
    ax.set_ylabel("PCA Component 2")
    ax.legend(loc="upper right", fontsize=8)

plt.tight_layout()
plt.show()
# Out:
# Explained Variance Ratio: [1.50917247e-01 7.53765851e-02 5.44983819e-02 4.29771394e-02
#  2.66802218e-02 2.29709428e-02 2.23582722e-02 2.12624054e-02
#  2.06477437e-02 1.94066446e-02 1.61153655e-02 1.29543468e-02
#  1.17216883e-02 1.11911595e-02 1.05971312e-02 9.80106182e-03
#  9.12884902e-03 8.32249969e-03 8.29396676e-03 7.94079900e-03
#  7.59852072e-03 7.46654347e-03 6.96994364e-03 6.48034178e-03
#  6.06499845e-03 5.85908256e-03 5.50697651e-03 5.39821107e-03
#  5.22578368e-03 4.99674678e-03 4.91457433e-03 4.54553589e-03
#  4.48937342e-03 4.32489766e-03 4.19385172e-03 4.05911077e-03
#  3.93552706e-03 3.92512279e-03 3.74680222e-03 3.63796018e-03
#  3.44573450e-03 3.33559513e-03 3.26668960e-03 3.14448774e-03
#  3.04352795e-03 3.03115649e-03 2.90051079e-03 2.85589625e-03
#  2.78850412e-03 2.75360490e-03 2.70818127e-03 2.63099000e-03
#  2.57294159e-03 2.54403241e-03 2.47623329e-03 2.41367612e-03
#  2.38514529e-03 2.31405091e-03 2.28098338e-03 2.20176461e-03
#  2.15864484e-03 2.13281927e-03 2.09951540e-03 2.06161593e-03
#  2.02600821e-03 1.98031194e-03 1.91867480e-03 1.90529181e-03
#  1.84866949e-03 1.81396061e-03 1.79369166e-03 1.76893419e-03
#  1.71864021e-03 1.69824588e-03 1.67078222e-03 1.66154478e-03
#  1.64805748e-03 1.62869156e-03 1.57864345e-03 1.57314003e-03
#  1.53513707e-03 1.51734846e-03 1.49923086e-03 1.46737136e-03
#  1.44653872e-03 1.42505462e-03 1.40785519e-03 1.39640190e-03
#  1.38004753e-03 1.36453740e-03 1.34756858e-03 1.31718698e-03
#  1.30266463e-03 1.30008999e-03 1.28593075e-03 1.26821187e-03
#  1.25402433e-03 1.22701121e-03 1.21484895e-03 1.21108536e-03
#  1.19656639e-03 1.15828903e-03 1.15130260e-03 1.13434356e-03
#  1.10428513e-03 1.09349552e-03 1.09067466e-03 1.08369265e-03
#  1.06972060e-03 1.06523046e-03 1.04486640e-03 1.03327050e-03
#  1.02072128e-03 9.95607465e-04 9.91897075e-04 9.81435529e-04
#  9.77100804e-04 9.69426241e-04 9.65643441e-04 9.53305571e-04
#  9.49481851e-04 9.41021019e-04 9.22189502e-04 9.05805849e-04
#  8.98467551e-04 8.94546742e-04 8.77503306e-04 8.69392883e-04
#  8.55863269e-04 8.51117773e-04 8.47562740e-04 8.34562990e-04
#  8.29884550e-04 8.20969115e-04 8.18330038e-04 8.03881616e-04
#  8.01486196e-04 7.91029830e-04 7.81588024e-04 7.75580935e-04
#  7.74678774e-04 7.67827383e-04 7.59386807e-04 7.54553359e-04
#  7.53702421e-04 7.39167910e-04 7.33262685e-04 7.21742050e-04
#  7.18321302e-04 7.16322451e-04 7.05400016e-04 6.98489661e-04
#  6.94578455e-04 6.83659280e-04 6.79898716e-04 6.72588940e-04
#  6.69858069e-04 6.59656362e-04 6.55854878e-04 6.54304167e-04
#  6.50534988e-04 6.47670007e-04 6.36566489e-04 6.31732517e-04
#  6.24673557e-04 6.22273132e-04 6.17560931e-04 6.15924597e-04
#  6.08371338e-04 6.07146998e-04 6.02305809e-04 5.99470863e-04
#  5.92230295e-04 5.88419498e-04 5.87456219e-04 5.81295113e-04
#  5.80124906e-04 5.71670185e-04 5.70544391e-04 5.68132324e-04
#  5.62840607e-04 5.59454900e-04 5.57229621e-04 5.55310166e-04
#  5.48552140e-04 5.40120876e-04 5.38819819e-04 5.34512685e-04
#  5.32138918e-04 5.28207049e-04 5.22909511e-04 5.19013091e-04
#  5.14176267e-04 5.11206337e-04 5.08417666e-04 5.04537777e-04
#  4.99872782e-04 4.96877590e-04 4.93678264e-04 4.91142971e-04
#  4.88571473e-04 4.87278361e-04 4.78977192e-04 4.76621324e-04
#  4.72897897e-04 4.72048356e-04 4.69101738e-04 4.67507110e-04
#  4.64490760e-04 4.64181125e-04 4.60758602e-04 4.58169729e-04
#  4.55572823e-04 4.51980188e-04 4.50162363e-04 4.48123319e-04
#  4.46298480e-04 4.42880410e-04 4.36459348e-04 4.35341382e-04
#  4.34484507e-04 4.31703695e-04 4.28924337e-04 4.27859050e-04
#  4.27312159e-04 4.24586207e-04 4.18727170e-04 4.17581847e-04
#  4.14321257e-04 4.12421068e-04 4.09967004e-04 4.04606253e-04
#  4.04299586e-04 4.00655292e-04 3.99351673e-04 3.98169213e-04
#  3.96824122e-04 3.94888135e-04 3.89447989e-04 3.87565728e-04
#  3.85740161e-04 3.83624516e-04 3.81443126e-04 3.81235906e-04
#  3.77500342e-04 3.74579569e-04 3.73013114e-04 3.69846064e-04
#  3.69568384e-04 3.68215260e-04 3.66281922e-04 3.64874810e-04
#  3.62176303e-04 3.60558799e-04 3.60114529e-04 3.57971643e-04
#  3.56332108e-04 3.55950178e-04 3.53307521e-04 3.52193369e-04
#  3.51357274e-04 3.48580739e-04 3.46605870e-04 3.45184322e-04
#  3.44122789e-04 3.42537242e-04 3.40846396e-04 3.38756101e-04
#  3.37348727e-04 3.36448080e-04 3.34181037e-04 3.32199736e-04
#  3.31604446e-04 3.28578462e-04 3.27193731e-04 3.26258800e-04
#  3.25097382e-04 3.23294022e-04 3.22067935e-04 3.19737737e-04
#  3.17925180e-04 3.16794962e-04 3.14762059e-04 3.14078323e-04
#  3.12150107e-04 3.11297423e-04 3.09449621e-04 3.08412651e-04
#  3.06998409e-04 3.04732239e-04 3.03472887e-04 3.01239023e-04
#  2.99853302e-04 2.99763167e-04 2.98042840e-04 2.96736049e-04
#  2.94897909e-04 2.93998339e-04 2.93383287e-04 2.92470795e-04
#  2.91081000e-04 2.89150194e-04 2.88422249e-04 2.86985101e-04
#  2.85680231e-04 2.84099428e-04 2.83200905e-04 2.82126042e-04
#  2.81509099e-04 2.78579595e-04 2.77836778e-04 2.76259874e-04
#  2.75837840e-04 2.74574209e-04 2.73517304e-04 2.71939789e-04
#  2.71172059e-04 2.70258199e-04 2.69213197e-04 2.67953583e-04
#  2.67679279e-04 2.65576266e-04 2.64501927e-04 2.62183836e-04
#  2.61272799e-04 2.60766887e-04 2.59452790e-04 2.58495304e-04
#  2.57244625e-04 2.56738625e-04 2.56268570e-04 2.55590858e-04
#  2.54112354e-04 2.53391860e-04 2.52003345e-04 2.51115678e-04
#  2.50701356e-04 2.49863224e-04 2.49050092e-04 2.47747259e-04
#  2.46876152e-04 2.46590760e-04 2.45011935e-04 2.44760537e-04
#  2.43029383e-04 2.42513473e-04 2.41623333e-04 2.40740759e-04
#  2.39677756e-04 2.39459507e-04 2.38337219e-04 2.38012726e-04
#  2.36539039e-04 2.34990279e-04 2.33973857e-04 2.33535029e-04
#  2.32619452e-04 2.32191567e-04 2.30775811e-04 2.30299425e-04
#  2.29470475e-04 2.28777673e-04 2.28213001e-04 2.27636934e-04
#  2.27290206e-04 2.25278141e-04 2.24774543e-04 2.23836672e-04
#  2.23296374e-04 2.21888724e-04 2.21026567e-04 2.20387228e-04
#  2.19380265e-04 2.18292393e-04 2.18121204e-04 2.17617562e-04
#  2.16505519e-04 2.15907203e-04 2.15304623e-04 2.14247397e-04
#  2.12936779e-04 2.12542087e-04 2.11738778e-04 2.11176899e-04
#  2.10821905e-04 2.09464924e-04 2.09041551e-04 2.08242433e-04
#  2.07443518e-04 2.06997589e-04 2.06524041e-04 2.06281431e-04
#  2.05059332e-04 2.04359036e-04 2.03865085e-04 2.03443604e-04
#  2.02095296e-04 2.01257208e-04 2.01016403e-04 2.00689406e-04
#  1.98682625e-04 1.98525100e-04 1.97643880e-04 1.97164030e-04
#  1.96679612e-04 1.95988323e-04 1.95391709e-04 1.94875800e-04
#  1.93917411e-04 1.93600543e-04 1.92822976e-04 1.92038089e-04
#  1.91775995e-04 1.91088810e-04 1.90042207e-04 1.89574945e-04
#  1.89113358e-04 1.88311576e-04 1.87565238e-04 1.87026613e-04
#  1.86784906e-04 1.86033605e-04 1.85588011e-04 1.85198922e-04
#  1.84476768e-04 1.83791883e-04 1.83293698e-04 1.82314208e-04
#  1.82082091e-04 1.81292591e-04 1.80982737e-04 1.79913754e-04
#  1.79477633e-04 1.78588176e-04 1.78114569e-04 1.77486290e-04
#  1.76907284e-04 1.76461035e-04 1.76199828e-04 1.75571913e-04
#  1.75222507e-04 1.74826971e-04 1.74314206e-04 1.73516921e-04
#  1.72980552e-04 1.72498418e-04 1.71581196e-04 1.71196138e-04
#  1.70968648e-04 1.69791936e-04 1.69716077e-04 1.69022154e-04
#  1.68204395e-04 1.67842096e-04 1.66807527e-04 1.66553407e-04
#  1.66004262e-04 1.65777761e-04 1.65171557e-04 1.64822544e-04
#  1.64398720e-04 1.64235986e-04 1.63989331e-04 1.63269055e-04
#  1.62702214e-04 1.62053053e-04 1.61504402e-04 1.61019692e-04
#  1.60514188e-04 1.59917297e-04 1.59550094e-04 1.59072515e-04
#  1.58680414e-04 1.58383889e-04 1.57468705e-04 1.56720082e-04
#  1.56268783e-04 1.56018839e-04 1.55563233e-04 1.55093483e-04
#  1.54266192e-04 1.54075678e-04 1.53351109e-04 1.53056360e-04
#  1.52274006e-04 1.51911256e-04 1.51768894e-04 1.51280619e-04
#  1.50492415e-04 1.50186141e-04 1.49793355e-04 1.49058498e-04
#  1.48757783e-04 1.48484396e-04 1.47761268e-04 1.47456725e-04
#  1.47180355e-04 1.46865161e-04 1.46124410e-04 1.45955171e-04
#  1.45345461e-04 1.45159909e-04 1.44546313e-04 1.44150312e-04
#  1.43919446e-04 1.43190817e-04 1.42878984e-04 1.42610821e-04
#  1.42136079e-04 1.41251978e-04 1.41147175e-04 1.41104538e-04
#  1.40524251e-04 1.39996569e-04 1.39515920e-04 1.39446667e-04
#  1.38869291e-04 1.38279502e-04 1.38044721e-04 1.37839612e-04
#  1.37012918e-04 1.36721079e-04 1.36268602e-04 1.36145798e-04
#  1.35832743e-04 1.35320195e-04 1.34873539e-04 1.34688438e-04
#  1.33833455e-04 1.33488313e-04 1.33110530e-04 1.32824265e-04
#  1.32737274e-04 1.32524336e-04 1.31494904e-04 1.31379871e-04
#  1.30996312e-04 1.30759581e-04 1.30523782e-04 1.30294007e-04
#  1.30207540e-04 1.29961540e-04 1.29318520e-04 1.29074309e-04
#  1.28845015e-04 1.28412765e-04 1.27435036e-04 1.27133288e-04
#  1.26725674e-04 1.26562678e-04 1.26412095e-04 1.26002473e-04
#  1.25781022e-04 1.25465871e-04 1.25343853e-04 1.25023056e-04
#  1.24790342e-04 1.24653830e-04 1.24391590e-04 1.23881706e-04
#  1.23577731e-04 1.23426013e-04 1.23063888e-04 1.22904443e-04
#  1.22133773e-04 1.22097888e-04 1.21657009e-04 1.21377343e-04
#  1.21174533e-04 1.20662109e-04 1.20157965e-04 1.19683486e-04
#  1.19649201e-04 1.19252698e-04 1.19218952e-04 1.18684671e-04
#  1.18504940e-04 1.18191769e-04 1.17945339e-04 1.17531876e-04
#  1.17322597e-04 1.17002834e-04 1.16729818e-04 1.16576746e-04]
# Number of Principal Components needed to retain 95% variance: 584

# %% [markdown]
# # Training the model - basic linear regression

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# -------------------------
# 1️⃣ Load PCA-Transformed Features
# -------------------------
folder_path = "/Users/etoileboots/Desktop/CAPSTONE/res_net/features_and_visualizations"  # Update if necessary
feature_files = [f for f in os.listdir(folder_path) if f.endswith(".npy")]

tract_features = {}

for file in feature_files:
    tract_name = file.replace(".npy", "")  # Extract tract identifier
    file_path = os.path.join(folder_path, file)
    features_dict = np.load(file_path, allow_pickle=True).item()
    tract_features[tract_name] = np.array(list(features_dict.values()))  # Convert to NumPy array

# Combine all feature vectors for PCA
all_features = np.vstack(list(tract_features.values()))

# Apply PCA - Keep enough components to explain 95% variance
pca = PCA(n_components=0.95)
pca.fit(all_features)

# -------------------------
# 2️⃣ Transform and Store Tract-Level PCA Features
# -------------------------
tract_pca_results = {}

for tract in tract_features:
    transformed_features = pca.transform(tract_features[tract])
    tract_pca_results[tract] = transformed_features.mean(axis=0)  # Use mean PCA features per tract

# Convert to DataFrame
pca_df = pd.DataFrame.from_dict(tract_pca_results, orient="index")

# Ensure correct column naming
pca_df.columns = [f"PCA_{i+1}" for i in range(pca_df.shape[1])]

# Convert index to a proper column for merging
pca_df.index.name = "GEOID20"
pca_df.reset_index(inplace=True)

# Print Results
print("PCA-transformed feature DataFrame shape:", pca_df.shape)
print(pca_df.head())
# Out:
# PCA-transformed feature DataFrame shape: (105, 585)
#                 GEOID20     PCA_1     PCA_2     PCA_3     PCA_4     PCA_5  \
# 0  features_48201451005  6.933016 -1.178870  0.411211  1.243453 -0.690079
# 1  features_48201410703  0.713550  0.336753  0.208136  1.711153  0.366040
# 2  features_48201332100 -2.695693 -0.181248  0.489524  0.963960 -0.610381
# 3  features_48201211900 -2.468397  0.036428  0.635333  0.813638 -0.289259
# 4  features_48201321800 -2.920471 -0.121099  1.017982  0.689486 -0.475308
#
#       PCA_6     PCA_7     PCA_8     PCA_9  ...   PCA_575   PCA_576   PCA_577  \
# 0 -0.227185  0.234747 -0.059961  0.740345  ...  0.010545 -0.009817 -0.014065
# 1  0.187640 -0.271740 -0.359627  0.654526  ... -0.015969  0.007023 -0.014365
# 2 -0.125726 -0.566191  0.205064  0.233138  ... -0.002387 -0.008881 -0.009274
# 3 -0.340211  0.905571  0.564092  0.624679  ... -0.000554  0.001270 -0.017447
# 4  0.389264 -0.145905  0.413126  0.423593  ... -0.006513 -0.000616  0.002533
#
#     PCA_578   PCA_579   PCA_580   PCA_581   PCA_582   PCA_583   PCA_584
# 0  0.001605 -0.015541  0.003934 -0.001759  0.023466 -0.001882 -0.004205
# 1 -0.008038  0.007496  0.001980 -0.008214 -0.002246 -0.000548  0.000816
# 2  0.001128 -0.003877  0.006001  0.006282 -0.005506 -0.007287  0.002639
# 3  0.003815 -0.002132 -0.007408  0.000198  0.007718 -0.007893  0.001637
# 4 -0.009773  0.002294 -0.006900 -0.003710  0.003352  0.000606  0.003489
#
# [5 rows x 585 columns]

# %%
# rename the geiod data frame 
pca_df.index = pca_df.index.astype(str)  # Ensure index is string type
pca_df["GEOID20"] = pca_df["GEOID20"].astype(str).str.replace("features_", "", regex=False)
pca_df.head()
# Out:
#        GEOID20     PCA_1     PCA_2     PCA_3     PCA_4     PCA_5     PCA_6  \
# 0  48201451005  6.933016 -1.178870  0.411211  1.243453 -0.690079 -0.227185
# 1  48201410703  0.713550  0.336753  0.208136  1.711153  0.366040  0.187640
# 2  48201332100 -2.695693 -0.181248  0.489524  0.963960 -0.610381 -0.125726
# 3  48201211900 -2.468397  0.036428  0.635333  0.813638 -0.289259 -0.340211
# 4  48201321800 -2.920471 -0.121099  1.017982  0.689486 -0.475308  0.389264
#
#       PCA_7     PCA_8     PCA_9  ...   PCA_575   PCA_576   PCA_577   PCA_578  \
# 0  0.234747 -0.059961  0.740345  ...  0.010545 -0.009817 -0.014065  0.001605
# 1 -0.271740 -0.359627  0.654526  ... -0.015969  0.007023 -0.014365 -0.008038
# 2 -0.566191  0.205064  0.233138  ... -0.002387 -0.008881 -0.009274  0.001128
# 3  0.905571  0.564092  0.624679  ... -0.000554  0.001270 -0.017447  0.003815
# 4 -0.145905  0.413126  0.423593  ... -0.006513 -0.000616  0.002533 -0.009773
#
#     PCA_579   PCA_580   PCA_581   PCA_582   PCA_583   PCA_584
# 0 -0.015541  0.003934 -0.001759  0.023466 -0.001882 -0.004205
# 1  0.007496  0.001980 -0.008214 -0.002246 -0.000548  0.000816
# 2 -0.003877  0.006001  0.006282 -0.005506 -0.007287  0.002639
# 3 -0.002132 -0.007408  0.000198  0.007718 -0.007893  0.001637
# 4  0.002294 -0.006900 -0.003710  0.003352  0.000606  0.003489
#
# [5 rows x 585 columns]

# %%
# SOCIODEMOGRAPHICS
# -------------------------
# 2️⃣ Load Sociodemographic Data
# -------------------------
csv_path = "/Volumes/MRDALLMAYR/data/census_data/census_data_harris_county_2022.csv"  # Update if necessary
socio_df = pd.read_csv(csv_path, dtype={"GEOID20": str})  # Load as string to avoid type mismatches

# Select relevant columns (remove categorical or ID columns)
target_columns = [
    "median_income", "pct_income_below_poverty", "pct_income_above_poverty", 
    "pct_no_vehicle", "pct_public_transport", "pct_commute_more_than_60"
]

socio_df = socio_df[["GEOID20"] + target_columns]  # Keep only relevant data
socio_df.head()
# Out:
#        GEOID20  median_income  pct_income_below_poverty  \
# 0  48201100001        84213.0                 15.502825
# 1  48201210400        51964.0                 21.742405
# 2  48201210500        44792.0                 23.209719
# 3  48201210600        83257.0                  4.208899
# 4  48201210700        49588.0                 19.429025
#
#    pct_income_above_poverty  pct_no_vehicle  pct_public_transport  \
# 0                 84.497175       11.012542              2.018966
# 1                 78.257595        7.478525             10.763012
# 2                 76.790281        8.078141              4.435058
# 3                 95.791101        8.131488              1.868512
# 4                 80.570975        1.986183              5.593804
#
#    pct_commute_more_than_60
# 0                  0.195542
# 1                  7.207207
# 2                  4.709302
# 3                  3.654224
# 4                  7.069767
